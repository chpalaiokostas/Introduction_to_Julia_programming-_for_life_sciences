# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Create a Julia file containing the code we used to create the coefficient of determination function (R_square). Apply this function is a new Julia session without hard copying its code.

# %%
include("R_square.jl")
using Main.R_square

# %%
X = [ones(15) rand(15)]
# Out:
# 15×2 Matrix{Float64}:
#  1.0  0.515614
#  1.0  0.273417
#  1.0  0.658253
#  1.0  0.707004
#  1.0  0.187832
#  1.0  0.137851
#  1.0  0.0467784
#  1.0  0.0912584
#  1.0  0.75023
#  1.0  0.407442
#  1.0  0.822167
#  1.0  0.969071
#  1.0  0.23684
#  1.0  0.421152
#  1.0  0.323814

# %%
y = X[:,2] - collect(rand(15))
# Out:
# 15-element Vector{Float64}:
#   0.4081082339670783
#   0.25316345254963024
#   0.1119405877749775
#  -0.19250187227029547
#  -0.33397441083713564
#  -0.416977022032181
#  -0.7104339301399071
#  -0.3359397187619598
#  -0.18118265977744297
#   0.060058982612785305
#   0.7542098514882548
#   0.6550427917450659
#  -0.03749826565036474
#  -0.2856959022619371
#  -0.0695690861363405

# %%
R²(X,y)
# Out:
# 0.5083163854289608

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Create a new enviroment called `Machine_learning`. On this environment add the following packages:
# * DataFrames
# * Plotly
# * MLSuite version 0.1.09.

# %%
mkdir("Machine_learning")
cd("Machine_learning")

# %%
using Pkg

# %%
Pkg.activate(".")
# Out:
#   Activating new project at `~/Library/CloudStorage/OneDrive-Sverigeslantbruksuniversitet/Teaching/Julia_SLU/Teaching_material/Day2/Machine_learning`

# %%
Pkg.status()
# Out:
# Status `~/Library/CloudStorage/OneDrive-Sverigeslantbruksuniversitet/Teaching/Julia_SLU/Teaching_material/Day2/Machine_learning/Project.toml` (empty project)

# %%
Pkg.add("DataFrames")
# Out:
#    Resolving package versions...
#     Updating `~/Library/CloudStorage/OneDrive-Sverigeslantbruksuniversitet/Teaching/Julia_SLU/Teaching_material/Day2/Machine_learning/Project.toml`
#   [a93c6f00] + DataFrames v1.6.1
#     Updating `~/Library/CloudStorage/OneDrive-Sverigeslantbruksuniversitet/Teaching/Julia_SLU/Teaching_material/Day2/Machine_learning/Manifest.toml`
#   [34da2185] + Compat v4.15.0
#   [a8cc5b0e] + Crayons v4.1.1
#   [9a962f9c] + DataAPI v1.16.0
#   [a93c6f00] + DataFrames v1.6.1
#   [864edb3b] + DataStructures v0.18.20
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [842dd82b] + InlineStrings v1.4.2
#   [41ab1584] + InvertedIndices v1.3.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [b964fa9f] + LaTeXStrings v1.3.1
#   [e1d29d7a] + Missings v1.2.0
#   [bac558e1] + OrderedCollections v1.6.3
#   [2dfb63ee] + PooledArrays v1.4.3
#   [aea7be01] + PrecompileTools v1.2.1
#   [21216c6a] + Preferences v1.4.3
#   [08abe8d2] + PrettyTables v2.3.2
#   [189a3867] + Reexport v1.2.2
#   [91c51154] + SentinelArrays v1.4.5
#   [a2af1166] + SortingAlgorithms v1.2.1
#   [892a3eda] + StringManipulation v0.3.4
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.12.0
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [9fa8497b] + Future
#   [b77e0a4c] + InteractiveUtils
#   [b27032c2] + LibCURL v0.6.3
#   [76f85450] + LibGit2
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [56ddb016] + Logging
#   [d6f4376e] + Markdown
#   [ca575930] + NetworkOptions v1.2.0
#   [44cfe95a] + Pkg v1.9.0
#   [de0858da] + Printf
#   [3fa0cd96] + REPL
#   [9a3f8284] + Random
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics v1.9.0
#   [fa267f1f] + TOML v1.0.3
#   [a4e569a6] + Tar v1.10.0
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll v1.0.2+0
#   [deac9b47] + LibCURL_jll v7.84.0+0
#   [29816b5a] + LibSSH2_jll v1.10.2+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.2+0
#   [14a3606d] + MozillaCACerts_jll v2022.10.11
#   [4536629a] + OpenBLAS_jll v0.3.21+4
#   [bea87d4a] + SuiteSparse_jll v5.10.1+6
#   [83775a58] + Zlib_jll v1.2.13+0
#   [8e850b90] + libblastrampoline_jll v5.8.0+0
#   [8e850ede] + nghttp2_jll v1.48.0+0
#   [3f19e933] + p7zip_jll v17.4.0+0

# %%
Pkg.add("Plotly")
# Out:
#    Resolving package versions...
#    Installed JSExpr ──────────────── v0.5.4
#    Installed Mustache ────────────── v1.0.20
#    Installed Kaleido_jll ─────────── v0.2.1+0
#    Installed PlotlyBase ──────────── v0.8.19
#    Installed PlotlyKaleido ───────── v2.2.4
#    Installed Blink ───────────────── v0.12.5
#    Installed Pidfile ─────────────── v1.3.0
#    Installed FunctionalCollections ─ v0.5.0
#    Installed WebSockets ──────────── v1.5.9
#    Installed PlotlyJS ────────────── v0.18.13
#    Installed ColorVectorSpace ────── v0.10.0
#    Installed URIs ────────────────── v1.5.1
#    Installed MbedTLS ─────────────── v1.1.9
#    Installed Observables ─────────── v0.5.5
#    Installed AssetRegistry ───────── v0.1.0
#    Installed Mux ─────────────────── v0.7.6
#    Installed Hiccup ──────────────── v0.2.2
#    Installed HTTP ────────────────── v0.9.17
#    Installed Widgets ─────────────── v0.6.6
#    Installed ColorSchemes ────────── v3.26.0
#    Installed BinDeps ─────────────── v1.0.2
#    Installed Plotly ──────────────── v0.4.1
#    Installed WebIO ───────────────── v0.8.21
#     Updating `~/Library/CloudStorage/OneDrive-Sverigeslantbruksuniversitet/Teaching/Julia_SLU/Teaching_material/Day2/Machine_learning/Project.toml`
#   [58dd65bb] + Plotly v0.4.1
#     Updating `~/Library/CloudStorage/OneDrive-Sverigeslantbruksuniversitet/Teaching/Julia_SLU/Teaching_material/Day2/Machine_learning/Manifest.toml`
#   [bf4720bc] + AssetRegistry v0.1.0
#   [9e28174c] + BinDeps v1.0.2
# ⌃ [ad839575] + Blink v0.12.5
#   [35d6a980] + ColorSchemes v3.26.0
#   [3da002f7] + ColorTypes v0.11.5
#   [c3611d14] + ColorVectorSpace v0.10.0
#   [5ae59095] + Colors v0.12.11
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [ffbed154] + DocStringExtensions v0.9.3
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [de31a74c] + FunctionalCollections v0.5.0
# ⌅ [cd3eb016] + HTTP v0.9.17
#   [9fb69e20] + Hiccup v0.2.2
#   [83e8ac13] + IniFile v0.5.1
#   [692b3bcd] + JLLWrappers v1.5.0
#   [97c1335a] + JSExpr v0.5.4
#   [682c06a0] + JSON v0.21.4
#   [50d2b5c4] + Lazy v0.15.1
#   [1914dd2f] + MacroTools v0.5.13
#   [739be429] + MbedTLS v1.1.9
#   [ffc61752] + Mustache v1.0.20
# ⌅ [a975b10e] + Mux v0.7.6
#   [510215fc] + Observables v0.5.5
#   [d96e819e] + Parameters v0.12.3
#   [69de0a69] + Parsers v2.8.1
#   [fa939f87] + Pidfile v1.3.0
#   [58dd65bb] + Plotly v0.4.1
#   [a03496cd] + PlotlyBase v0.8.19
#   [f0f68f2c] + PlotlyJS v0.18.13
#   [f2990250] + PlotlyKaleido v2.2.4
#   [ae029012] + Requires v1.3.0
#   [62fd8b95] + TensorCore v0.1.1
#   [30578b45] + URIParser v0.4.1
#   [5c2747f8] + URIs v1.5.1
#   [3a884ed6] + UnPack v1.0.2
#   [0f1e0344] + WebIO v0.8.21
# ⌃ [104b5d7c] + WebSockets v1.5.9
#   [cc8bc4a8] + Widgets v0.6.6
#   [f7e6163d] + Kaleido_jll v0.2.1+0
#   [8ba89e20] + Distributed
#   [a63ad114] + Mmap
#   [8dfed614] + Test
#         Info Packages marked with ⌃ and ⌅ have new versions available, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
#     Building WebIO ───→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/0eef0765186f7452e52236fa42ca8c9b3c11c6e3/build.log`
#     Building Blink ───→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/08d0b679fd7caa49e2bca9214b131289e19808c0/build.log`
#     Building PlotlyJS → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/e62d886d33b81c371c9d4e2f70663c0637f19459/build.log`
# Precompiling project...
#   ✓ IniFile
#   ✓ Pidfile
#   ✓ Observables
#   ✓ FunctionalCollections
#   ✓ URIs
#   ✓ Mustache
#   ✓ Hiccup
#   ✓ URIParser
#   ✓ Kaleido_jll
#   ✓ MbedTLS
#   ✓ AssetRegistry
#   ✓ PlotlyKaleido
#   ✓ Widgets
#   ✓ BinDeps
#   ✓ HTTP
#   ✓ ColorVectorSpace
#   ✓ WebSockets
#   ✓ Mux
#   ✓ WebIO
#   ✓ JSExpr
#   ✓ Blink
#   ✓ ColorSchemes
#   ✓ PlotlyBase
#   ✓ PlotlyJS
#   ✓ Plotly
#   25 dependencies successfully precompiled in 18 seconds. 44 already precompiled.

# %%
Pkg.add(name="MLSuite", version="0.1.09")
# Out:
#    Resolving package versions...
#    Installed Blosc_jll ───────── v1.21.5+0
#    Installed OpenSSL_jll ─────── v3.0.14+0
#    Installed libaec_jll ──────── v1.1.2+0
#    Installed MPICH_jll ───────── v4.2.2+0
#    Installed Conda ───────────── v1.10.2
#    Installed Zstd_jll ────────── v1.5.6+0
#    Installed PyCallUtils ─────── v0.2.3
#    Installed LLVMOpenMP_jll ──── v15.0.7+0
#    Installed MLSuiteBase ─────── v0.2.13
#    Installed ScikitLearnBase ─── v0.5.0
#    Installed Hwloc_jll ───────── v2.11.1+0
#    Installed MicrosoftMPI_jll ── v10.1.4+2
#    Installed PyCall ──────────── v1.96.4
#    Installed OpenMPI_jll ─────── v5.0.4+0
#    Installed TimerOutputs ────── v0.5.24
#    Installed HDF5 ────────────── v0.13.6
#    Installed HDF5Utils ───────── v0.1.46
#    Installed MPIPreferences ──── v0.1.11
#    Installed Iconv ───────────── v0.1.0
#    Installed Lz4_jll ─────────── v1.10.0+0
#    Installed MPItrampoline_jll ─ v5.4.0+0
#    Installed FillArrays ──────── v0.12.8
#    Installed DataValues ──────── v0.4.13
#    Installed TableTraitsUtils ── v1.0.2
#    Installed Glob ────────────── v1.3.1
#    Installed HDF5_jll ────────── v1.14.2+1
#    Installed ArgParse ────────── v1.2.0
#    Installed PandasLite ──────── v0.1.13
#    Installed SVMLightWriter ──── v0.1.1
#    Installed MLSuite ─────────── v0.1.9
#    Installed BSON ────────────── v0.2.6
#    Installed TextWrap ────────── v1.0.2
#    Installed DiskArrays ──────── v0.2.13
#    Installed Blosc ───────────── v0.7.3
#     Updating `~/Library/CloudStorage/OneDrive-Sverigeslantbruksuniversitet/Teaching/Julia_SLU/Teaching_material/Day2/Machine_learning/Project.toml`
# ⌃ [fd36aebc] + MLSuite v0.1.9
#     Updating `~/Library/CloudStorage/OneDrive-Sverigeslantbruksuniversitet/Teaching/Julia_SLU/Teaching_material/Day2/Machine_learning/Manifest.toml`
#   [c7e460c6] + ArgParse v1.2.0
# ⌅ [fbb218c0] + BSON v0.2.6
#   [a74b3585] + Blosc v0.7.3
#   [8f4d0f93] + Conda v1.10.2
#   [e7dc6d0d] + DataValues v0.4.13
# ⌅ [3c3547ce] + DiskArrays v0.2.13
#   [e2ba6199] + ExprTools v0.1.10
# ⌅ [1a297f60] + FillArrays v0.12.8
#   [c27321d9] + Glob v1.3.1
# ⌅ [f67ccb44] + HDF5 v0.13.6
#   [2ec8e600] + HDF5Utils v0.1.46
#   [f60d2a9e] + Iconv v0.1.0
# ⌃ [fd36aebc] + MLSuite v0.1.9
#   [d01462b0] + MLSuiteBase v0.2.13
#   [3da0fdf6] + MPIPreferences v0.1.11
#   [f5117550] + PandasLite v0.1.13
#   [92933f4c] + ProgressMeter v1.10.2
#   [438e738f] + PyCall v1.96.4
#   [02651160] + PyCallUtils v0.2.3
#   [b51eda20] + SVMLightWriter v0.1.1
#   [6e75b9c4] + ScikitLearnBase v0.5.0
#   [382cd787] + TableTraitsUtils v1.0.2
#   [b718987f] + TextWrap v1.0.2
#   [a759f4b9] + TimerOutputs v0.5.24
#   [81def892] + VersionParsing v1.3.0
#   [0b7ba130] + Blosc_jll v1.21.5+0
# ⌃ [0234f1f7] + HDF5_jll v1.14.2+1
#   [e33a78d0] + Hwloc_jll v2.11.1+0
#   [1d63c593] + LLVMOpenMP_jll v15.0.7+0
#   [5ced341a] + Lz4_jll v1.10.0+0
#   [7cb0a576] + MPICH_jll v4.2.2+0
#   [f1f71cc9] + MPItrampoline_jll v5.4.0+0
#   [9237b28f] + MicrosoftMPI_jll v10.1.4+2
#   [fe0851c0] + OpenMPI_jll v5.0.4+0
#   [458c3c95] + OpenSSL_jll v3.0.14+0
#   [3161d3a3] + Zstd_jll v1.5.6+0
#   [477f73a3] + libaec_jll v1.1.2+0
#   [4af54fe1] + LazyArtifacts
#         Info Packages marked with ⌃ and ⌅ have new versions available, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
#     Building Conda ──→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/b19db3927f0db4151cb86d073689f2428e524576/build.log`
#     Building PyCall ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/9816a3826b0ebf49ab4926e2b18842ad8b5c8f04/build.log`
#     Building HDF5 ───→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/0713cbabdf855852dfab3ce6447c87145f3d9ea8/build.log`
#     Building MLSuite → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/e07f194561ce81c854ed47cb52ecf66c777e4d8f/build.log`
# Precompiling project...
#   ✓ Iconv
#   ✓ TextWrap
#   ✓ Glob
#   ✓ ScikitLearnBase
#   ✓ DiskArrays
#   ✓ SVMLightWriter
#   ✓ BSON
#   ✓ DataValues
#   ✓ OpenSSL_jll
#   ✓ MPIPreferences
#   ✓ MicrosoftMPI_jll
#   ✓ Zstd_jll
#   ✓ Hwloc_jll
#   ✓ LLVMOpenMP_jll
#   ✓ FillArrays
#   ✓ Lz4_jll
#   ✓ libaec_jll
#   ✓ MLSuiteBase
#   ✓ Conda
#   ✓ MPItrampoline_jll
#   ✓ TableTraitsUtils
#   ✓ OpenMPI_jll
#   ✓ ArgParse
#   ✓ MPICH_jll
#   ✓ Blosc_jll
#   ✓ Blosc
#   ✓ HDF5_jll
#   ✓ TimerOutputs
#   ✓ HDF5
#   ✓ HDF5Utils
#   ✓ PyCall
#   ✓ PyCallUtils
#   ✓ PandasLite
#   ✓ MLSuite
#   34 dependencies successfully precompiled in 23 seconds. 72 already precompiled.
#   5 dependencies had warnings during precompilation:
# ┌ PandasLite [f5117550-fbe7-11e9-2624-0f3969024220]
# │  WARNING: Method definition getindex(PyCall.PyObject, Union{AbstractString, Symbol}) in module PyCall at /Users/christos/.julia/packages/PyCall/1gn3u/src/PyCall.jl:349 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:6.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Union{AbstractString, Symbol}) in module PyCall at /Users/christos/.julia/packages/PyCall/1gn3u/src/PyCall.jl:358 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:7.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Integer) in module PyCall at deprecated.jl:103 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:9.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Integer, Integer) in module PyCall at deprecated.jl:103 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:10.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Integer...) in module PyCall at deprecated.jl:103 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:11.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Integer) in module PyCall at deprecated.jl:103 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:12.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Integer, Integer) in module PyCall at deprecated.jl:103 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:13.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Integer...) in module PyCall at deprecated.jl:103 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:14.
# │    ** incremental compilation may be fatally broken for this module **
# └
# ┌ MLSuite [fd36aebc-0777-11ea-1be3-eb1bdc5c01e1]
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Integer...) in module PyCall at deprecated.jl:103 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:53.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Integer, Integer) in module PyCall at deprecated.jl:103 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:52.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Integer) in module PyCall at deprecated.jl:103 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:51.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Union{AbstractString, Symbol}) in module PyCall at /Users/christos/.julia/packages/PyCall/1gn3u/src/PyCall.jl:358 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:46.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Integer...) in module PyCall at deprecated.jl:103 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:50.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Integer, Integer) in module PyCall at deprecated.jl:103 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:49.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Integer) in module PyCall at deprecated.jl:103 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:48.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Union{AbstractString, Symbol}) in module PyCall at /Users/christos/.julia/packages/PyCall/1gn3u/src/PyCall.jl:349 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:45.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition jlwrap_iterator(Any) in module PyCall at /Users/christos/.julia/packages/PyCall/1gn3u/src/pyiterator.jl:137 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:55.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition (::Type{PyCall.PyObject})(Base.Colon) in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:38 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/PandasLite.jl:121.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Integer...) in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:50 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:11.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Any...) in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:41 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:2.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Any) in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:40 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:1.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Integer, Integer) in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:49 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:10.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Integer) in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:48 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:9.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Union{AbstractString, Symbol}) in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:45 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:6.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Integer...) in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:53 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:14.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Any...) in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:43 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:4.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Any) in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:42 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:3.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Integer, Integer) in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:52 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:13.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Integer) in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:51 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:12.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Union{AbstractString, Symbol}) in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:46 overwritten in module PandasLite at /Users/christos/.julia/packages/PandasLite/lHOFz/src/index.jl:7.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition kwcall(Any, typeof(HDF5.h5open), Function, Any...) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:693 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:34.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition kwcall(Any, typeof(HDF5.h5open), AbstractString, AbstractString, Any...) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:660 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:1.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition kwcall(Any, typeof(HDF5.h5open), AbstractString) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:660 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:1.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition close(HDF5.HDF5File) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:780 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:43.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition _setindex!(HDF5.HDF5Dataset, Type, Array{T, N} where N where T, Union{Int64, Base.AbstractRange{Int64}}...) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:1803 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/hyperslab.jl:16.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition h5open(Function, Any...) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:693 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:34.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition h5open(AbstractString, AbstractString, Any...) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:660 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:1.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition h5open(AbstractString) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:660 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:1.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition _getindex(HDF5.HDF5Dataset, Type, Union{Int64, Base.AbstractRange{Int64}}...) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:1771 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/hyperslab.jl:1.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition _Array(AbstractArray{T, N}) where {T, N} in module DiskArrays at /Users/christos/.julia/packages/DiskArrays/iCPtn/src/array.jl:33 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/diskarrays.jl:129.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition lower(Any) in module Writer at /Users/christos/.julia/packages/JSON/93Ea8/src/Writer.jl:43 overwritten in module MLSuiteBase at /Users/christos/.julia/packages/MLSuiteBase/TvMpg/src/MLSuiteBase.jl:127.
# │    ** incremental compilation may be fatally broken for this module **
# └
# ┌ PyCallUtils [02651160-e6c3-11e9-0e2a-551f75d9519e]
# │  WARNING: Method definition getindex(PyCall.PyObject, Union{AbstractString, Symbol}) in module PyCall at /Users/christos/.julia/packages/PyCall/1gn3u/src/PyCall.jl:349 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:45.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Union{AbstractString, Symbol}) in module PyCall at /Users/christos/.julia/packages/PyCall/1gn3u/src/PyCall.jl:358 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:46.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Integer) in module PyCall at deprecated.jl:103 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:48.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Integer, Integer) in module PyCall at deprecated.jl:103 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:49.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition getindex(PyCall.PyObject, Integer...) in module PyCall at deprecated.jl:103 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:50.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Integer) in module PyCall at deprecated.jl:103 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:51.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Integer, Integer) in module PyCall at deprecated.jl:103 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:52.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition setindex!(PyCall.PyObject, Any, Integer...) in module PyCall at deprecated.jl:103 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:53.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition jlwrap_iterator(Any) in module PyCall at /Users/christos/.julia/packages/PyCall/1gn3u/src/pyiterator.jl:137 overwritten in module PyCallUtils at /Users/christos/.julia/packages/PyCallUtils/GJ7TW/src/PyCallUtils.jl:55.
# │    ** incremental compilation may be fatally broken for this module **
# └
# ┌ MLSuiteBase [d01462b0-16b5-11ea-1c8e-eb7ed7586854]
# │  WARNING: Method definition lower(Any) in module Writer at /Users/christos/.julia/packages/JSON/93Ea8/src/Writer.jl:43 overwritten in module MLSuiteBase at /Users/christos/.julia/packages/MLSuiteBase/TvMpg/src/MLSuiteBase.jl:127.
# │    ** incremental compilation may be fatally broken for this module **
# └
# ┌ HDF5Utils [2ec8e600-e6c3-11e9-3904-61c7e8636276]
# │  WARNING: Method definition _Array(AbstractArray{T, N}) where {T, N} in module DiskArrays at /Users/christos/.julia/packages/DiskArrays/iCPtn/src/array.jl:33 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/diskarrays.jl:129.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition h5open(AbstractString) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:660 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:1.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition h5open(AbstractString, AbstractString, Any...) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:660 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:1.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition kwcall(Any, typeof(HDF5.h5open), AbstractString) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:660 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:1.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition kwcall(Any, typeof(HDF5.h5open), AbstractString, AbstractString, Any...) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:660 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:1.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition h5open(Function, Any...) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:693 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:34.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition kwcall(Any, typeof(HDF5.h5open), Function, Any...) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:693 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:34.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition close(HDF5.HDF5File) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:780 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/io.jl:43.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition _getindex(HDF5.HDF5Dataset, Type, Union{Int64, Base.AbstractRange{Int64}}...) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:1771 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/hyperslab.jl:1.
# │    ** incremental compilation may be fatally broken for this module **
# │
# │  WARNING: Method definition _setindex!(HDF5.HDF5Dataset, Type, Array{T, N} where N where T, Union{Int64, Base.AbstractRange{Int64}}...) in module HDF5 at /Users/christos/.julia/packages/HDF5/T1b9x/src/HDF5.jl:1803 overwritten in module HDF5Utils at /Users/christos/.julia/packages/HDF5Utils/bFZUF/src/hyperslab.jl:16.
# │    ** incremental compilation may be fatally broken for this module **
# └

# %%
Pkg.status()
# Out:
# Status `~/Library/CloudStorage/OneDrive-Sverigeslantbruksuniversitet/Teaching/Julia_SLU/Teaching_material/Day2/Machine_learning/Project.toml`
#   [a93c6f00] DataFrames v1.6.1
# ⌃ [fd36aebc] MLSuite v0.1.9
#   [58dd65bb] Plotly v0.4.1
# Info Packages marked with ⌃ have new versions available and may be upgradable.
